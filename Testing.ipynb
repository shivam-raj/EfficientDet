# %%
from model import efficientdet

# %%
_,box=efficientdet(phi=0,weighted_bifpn=True,freeze_bn=True)

# %%
box.summary()
# Out:
# Model: "efficientdet_p"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 512, 512, 3) 0
# __________________________________________________________________________________________________
# stem_conv (Conv2D)              (None, 256, 256, 32) 864         input_1[0][0]
# __________________________________________________________________________________________________
# stem_bn (BatchNormalization)    (None, 256, 256, 32) 128         stem_conv[0][0]
# __________________________________________________________________________________________________
# stem_activation (Activation)    (None, 256, 256, 32) 0           stem_bn[0][0]
# __________________________________________________________________________________________________
# ...

# %%
# !python3 train.py --snapshot imagenet --gpu 0 --compute-val-loss --batch-size 4 --steps 5 --set 2014 coco /media/shivam/Elements/Dataset/coco
# Out:
# 2020-04-14 01:22:35.853707: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/shivam/.mujoco/mujoco200/bin:/home/shivam/.mujoco/mjpro150/bin
# 2020-04-14 01:22:35.853799: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: :/home/shivam/.mujoco/mujoco200/bin:/home/shivam/.mujoco/mjpro150/bin
# 2020-04-14 01:22:35.853813: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# ...

# %%
# !python3 train.py --snapshot 'xxx.h5' --gpu 0 --compute-val-loss coco /media/shivam/Elements/Dataset/coco
